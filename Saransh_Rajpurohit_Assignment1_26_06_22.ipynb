# %%
# Saransh-Rajpurohit-Assignment1-26-06-22

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dft=pd.read_csv('/content/titles.csv')

# %%
dfc=pd.read_csv('/content/credits.csv')

# %%
dfct=pd.merge( dft, dfc, how="outer", on=["id"] )

# %%
dfct.sample(20)
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5806 non-null   object
#  1   title                 5805 non-null   object
#  2   type                  5806 non-null   object
#  3   description           5788 non-null   object
#  4   release_year          5806 non-null   int64
#  5   age_certification     3196 non-null   object
#  6   runtime               5806 non-null   int64
#  7   genres                5806 non-null   object
#  8   production_countries  5806 non-null   object
#  9   seasons               2047 non-null   float64
#  10  imdb_id               5362 non-null   object
#  11  imdb_score            5283 non-null   float64
#  12  imdb_votes            5267 non-null   float64
#  13  tmdb_popularity       5712 non-null   float64
#  14  tmdb_score            5488 non-null   float64
# ...

# %%
dft.corr()
# Out:
#                  release_year   runtime   seasons  imdb_score  imdb_votes  \
# release_year         1.000000 -0.211076 -0.505831   -0.102849   -0.196988
# runtime             -0.211076  1.000000 -0.132740   -0.159297    0.138610
# seasons             -0.505831 -0.132740  1.000000    0.097727    0.212645
# imdb_score          -0.102849 -0.159297  0.097727    1.000000    0.189954
# imdb_votes          -0.196988  0.138610  0.212645    0.189954    1.000000
# tmdb_popularity      0.025628 -0.027493  0.331362    0.023159    0.201813
# tmdb_score           0.049107 -0.285232  0.026796    0.587675    0.109720
#
#                  tmdb_popularity  tmdb_score
# release_year            0.025628    0.049107
# runtime                -0.027493   -0.285232
# seasons                 0.331362    0.026796
# imdb_score              0.023159    0.587675
# imdb_votes              0.201813    0.109720
# tmdb_popularity         1.000000    0.068405
# tmdb_score              0.068405    1.000000

# %%
# imdb_score increases as seasons increases and decreases when release_year and runtime increases
# imdb_votes increases as runtime and seasons increases and decreases when release_year increases
# tmdb_popularity increases as seasons and release_year increases and decreases when runtime increases
# tmdb_score increases as seasons and release_year increases and decreases when runtime increases

# %%
dfc.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
print(dft.shape)
print(dfc.shape)
# Out:
# (5806, 15)
# (77213, 5)

# %%
dft['production_countries'].value_counts()
# Out:
# ['US']                      1950
# ['IN']                       605
# ['JP']                       266
# []                           232
# ['GB']                       219
#                             ...
# ['PR', 'US', 'GB', 'CN']       1
# ['GB', 'US', 'FR']             1
# ['IT', 'ES', 'FR']             1
# ['GB', 'US', 'CZ']             1
# ['NG', 'CA']                   1
# Name: production_countries, Length: 449, dtype: int64

# %%
# most movies and shows are made in 'US'

# %%
dft['type'].value_counts()
# Out:
# MOVIE    3759
# SHOW     2047
# Name: type, dtype: int64

# %%
# There are 3759 movies and 2047 shows on netflix

# %%
dft['seasons'].value_counts()
# Out:
# 1.0     1187
# 2.0      374
# 3.0      181
# 4.0      116
# 5.0       76
# 6.0       40
# 7.0       16
# 8.0       14
# 9.0        9
# 11.0       7
# 10.0       5
# 15.0       4
# 12.0       4
# 24.0       3
# 13.0       2
# 14.0       2
# 19.0       1
# 18.0       1
# 29.0       1
# 21.0       1
# 42.0       1
# 39.0       1
# 37.0       1
# Name: seasons, dtype: int64

# %%
# most shows and movies have a single season

# %%
dfc['name'].value_counts()
# Out:
# Shah Rukh Khan         30
# Anupam Kher            25
# Boman Irani            25
# Kareena Kapoor Khan    25
# Paresh Rawal           22
#                        ..
# Jacky Cai               1
# Jan Tse                 1
# Tsui Ching-Man          1
# Sam Chan Yu-Sum         1
# Yemi Amodu              1
# Name: name, Length: 53687, dtype: int64

# %%
# Shah Rukh Khan has done the most number of movies and shows

# %%
dft['genres'].value_counts()
# Out:
# ['comedy']                                            510
# ['drama']                                             350
# ['documentation']                                     320
# ['comedy', 'drama']                                   141
# ['drama', 'comedy']                                   128
#                                                      ...
# ['drama', 'family', 'comedy', 'music']                  1
# ['drama', 'thriller', 'western']                        1
# ['comedy', 'thriller', 'drama', 'action', 'crime']      1
# ['romance', 'drama', 'history', 'european']             1
# ['family', 'comedy', 'animation']                       1
# Name: genres, Length: 1626, dtype: int64

# %%
# Most movies and shows are of 'comedy' genre

# %%
dft['age_certification'].value_counts()
# Out:
# TV-MA    841
# R        575
# TV-14    470
# PG-13    440
# PG       246
# TV-PG    186
# G        131
# TV-Y7    112
# TV-Y     105
# TV-G      76
# NC-17     14
# Name: age_certification, dtype: int64

# %%
# most movies and shows are TV-MA rated

# %%
plt.scatter(dft['imdb_votes'],dft['tmdb_popularity'])

# %%
# Most movies and shows have imdb_votes 0 to 0.8e6 and tmdb_popularity 0 to 750
# imdb_votes significantly increase as tmdb_popularity increase

# %%
plt.scatter(dft['runtime'],dft['tmdb_popularity'])

# %%
# Most movies and shows have runtime 0 to 200 and tmdb_popularity 0 to 750
# runtime decrease as tmdb_popularity increase

# %%
plt.scatter(dft['imdb_score'],dft['tmdb_popularity'])

# %%
# Most movies and shows have imdb_score 0 to 9 and tmdb_popularity 0 to 750
# imdb_score slightly increase as tmdb_popularity increase

# %%
plt.scatter(dft['tmdb_score'],dft['tmdb_popularity'])

# %%
# Most movies and shows have tmdb_score 2 to 10 and tmdb_popularity 0 to 750
# tmdb_score increase as tmdb_popularity increase

# %%
plt.scatter(dft['imdb_score'],dft['imdb_votes'])

# %%
# Most movies and shows have imdb_votes 0 to 0.8e6 and imdb_score 2 to 9
# imdb_votes significantly increase as imdb_score increase

# %%
a1=dfct.sort_values(by=['imdb_score'],ascending=False)
a1 = a1.reset_index()
a2=dfct.sort_values(by=['imdb_votes'],ascending=False)
a2 = a2.reset_index()
a3=dfct.sort_values(by=['tmdb_popularity'],ascending=False)
a3 = a3.reset_index()
a4=dfct.sort_values(by=['tmdb_score'],ascending=False)
a4 = a4.reset_index()

# %%
a1.head()
# Out:
#    index        id         title  type  \
# 0  44200  ts265844      #ABtalks  SHOW
# 1  13279  ts160526      Khawatir  SHOW
# 2   4569       ts4  Breaking Bad  SHOW
# 3   4571       ts4  Breaking Bad  SHOW
# 4   4574       ts4  Breaking Bad  SHOW
#
#                                          description  release_year  \
# 0  #ABtalks is a YouTube interview show hosted by...          2018
# 1  A TV show devoted to help young people to be m...          2005
# 2  When Walter White, a New Mexico chemistry teac...          2008
# 3  When Walter White, a New Mexico chemistry teac...          2008
# 4  When Walter White, a New Mexico chemistry teac...          2008
#
#   age_certification  runtime                          genres  \
# 0             TV-PG       68                              []
# 1             TV-14       20                     ['reality']
# 2             TV-MA       48  ['drama', 'thriller', 'crime']
# 3             TV-MA       48  ['drama', 'thriller', 'crime']
# ...

# %%
# Khawatir and #ABtalks has highest imdb_score of 9.6

# %%
a2.head()
# Out:
#    index       id      title   type  \
# 0   4867  tm92641  Inception  MOVIE
# 1   4866  tm92641  Inception  MOVIE
# 2   4854  tm92641  Inception  MOVIE
# 3   4855  tm92641  Inception  MOVIE
# 4   4856  tm92641  Inception  MOVIE
#
#                                          description  release_year  \
# 0  Cobb, a skilled thief who commits corporate es...          2010
# 1  Cobb, a skilled thief who commits corporate es...          2010
# 2  Cobb, a skilled thief who commits corporate es...          2010
# 3  Cobb, a skilled thief who commits corporate es...          2010
# 4  Cobb, a skilled thief who commits corporate es...          2010
#
#   age_certification  runtime                                    genres  \
# 0             PG-13      148  ['scifi', 'music', 'thriller', 'action']
# 1             PG-13      148  ['scifi', 'music', 'thriller', 'action']
# 2             PG-13      148  ['scifi', 'music', 'thriller', 'action']
# ...

# %%
# Inception has highest imdb_votes of 2268288.0

# %%
a3.head()
# Out:
#    index         id               title   type  \
# 0  66905  tm1191224  365 Days: This Day  MOVIE
# 1  66912  tm1191224  365 Days: This Day  MOVIE
# 2  66914  tm1191224  365 Days: This Day  MOVIE
# 3  66911  tm1191224  365 Days: This Day  MOVIE
# 4  66902  tm1191224  365 Days: This Day  MOVIE
#
#                                          description  release_year  \
# 0  Laura and Massimo are back and hotter than eve...          2022
# 1  Laura and Massimo are back and hotter than eve...          2022
# 2  Laura and Massimo are back and hotter than eve...          2022
# 3  Laura and Massimo are back and hotter than eve...          2022
# 4  Laura and Massimo are back and hotter than eve...          2022
#
#   age_certification  runtime                genres production_countries  \
# 0               NaN      111  ['romance', 'drama']               ['PL']
# 1               NaN      111  ['romance', 'drama']               ['PL']
# ...

# %%
# 365 Days: This Day has highest tmdb_popularity of 1823.374

# %%
a4.head(20)
# Out:
#     index        id                                           title   type  \
# 0   77584  ts271048              Mighty Little Bheem: Kite Festival   SHOW
# 1   45754  tm445852                          Three Words to Forever  MOVIE
# 2   48066   ts90448             The Hateful Eight: Extended Version   SHOW
# 3   48065   ts90448             The Hateful Eight: Extended Version   SHOW
# 4   48064   ts90448             The Hateful Eight: Extended Version   SHOW
# 5   48063   ts90448             The Hateful Eight: Extended Version   SHOW
# 6   48062   ts90448             The Hateful Eight: Extended Version   SHOW
# 7   45792  ts104093                          Dance & Sing With True   SHOW
# 8   45782  ts236619  Loo Loo Kids Johny & Friends Musical Adventure   SHOW
# 9   45759  tm445852                          Three Words to Forever  MOVIE
# 10  45758  tm445852                          Three Words to Forever  MOVIE
# ...

# %%
# Mighty Little Bheem: Kite Festival has highest tmdb_score of 10.0 and imdb_score = 8.8

# %%
x1=dft['release_year']
x2=dft['runtime']
x3=dft['seasons']
y1=dft['imdb_score']
y2=dft['imdb_votes']
y3=dft['tmdb_popularity']
y4=dft['tmdb_score']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
w0=3
w1= -0.011522759914207082
w2=1
w3=-1.0126105167364683e-05
for i in range(119):
 yh=w0+w1*x1+w2*x2+w3*x3
 dew0=-2*((y1-yh)).mean()
 dew1=-2*((y1-yh*x1)).mean()
 dew2=-2*((y1-yh*x2)).mean()
 dew3=-2*((y1-yh*x3)).mean()
 lr=0.000000001
 w0=w0-lr*dew0
 w1=w1-lr*dew1
 w2=w2-lr*dew2
 w3=w3-lr*dew3
 mse=((y1-yh)**2).mean()
 print(i,mse)
# Out:
# 0 434.5749475712105
# 1 431.1879641782312
# 2 427.87285402944934
# 3 424.62831365275053
# 4 421.45306183542124
# 5 418.3458392540696
# 6 415.30540811062036
# 7 412.3305517742866
# 8 409.420074429419
# 9 406.5728007291388
# 10 403.787575454659
# 11 401.06326318020047
# 12 398.39874794341307
# 13 395.79293292121065
# 14 393.2447401109319
# 15 390.7531100167411
# 16 388.3170013411815
# 17 385.9353906817985
# 18 383.6072722327502
# 19 381.3316574913223
# 20 379.107574969268
# 21 376.93406990889594
# 22 374.81020400382585
# 23 372.7350551243359
# 24 370.70771704723035
# 25 368.72729919014876
# 26 366.7929263502482
# 27 364.9037384471839
# 28 363.05889027032117
# 29 361.25755123010606
# 30 359.4989051135314
# 31 357.78214984362546
# 32 356.10649724290306
# 33 354.4711728007108
# 34 352.87541544440484
# 35 351.31847731429644
# 36 349.7996235423064
# 37 348.3181320342654
# 38 346.8732932558018
# 39 345.4644100217589
# 40 344.0907972890819
# 41 342.7517819531198
# 42 341.4467026472859
# ...

# %%
print(w0,w1,w2,w3)
# Out:
# 2.9999988606271977 -0.017191216209262516 0.9998187220414166 -1.3246595043572136e-05

# %%
# imdb_score = 3 + -0.01152 release_year + 1 runtime - 1.0126e-6 seasons

# %%
w0=-1000
w1=0.08
w2=20
w3=10
for i in range(100):
 yh=w0+w1*x1+w2*x2+w3*x3
 dew0=-2*((y2-yh)).mean()
 dew1=-2*((y2-yh*x1)).mean()
 dew2=-2*((y2-yh*x2)).mean()
 dew3=-2*((y2-yh*x3)).mean()
 lr=0.000000002
 w0=w0-lr*dew0
 w1=w1-lr*dew1
 w2=w2-lr*dew2
 w3=w3-lr*dew3
 mse=((y2-yh)**2).mean()
 print(i,mse)
# Out:
# 0 5351227445.918687
# 1 5351197660.920822
# 2 5351168362.0388155
# 3 5351139541.3126135
# 4 5351111190.913234
# 5 5351083303.140584
# 6 5351055870.421317
# 7 5351028885.306716
# 8 5351002340.470636
# 9 5350976228.707454
# 10 5350950542.93007
# 11 5350925276.167941
# 12 5350900421.565146
# 13 5350875972.378476
# 14 5350851921.975577
# 15 5350828263.833091
# 16 5350804991.534871
# 17 5350782098.770185
# 18 5350759579.331979
# 19 5350737427.115155
# 20 5350715636.114883
# 21 5350694200.424944
# 22 5350673114.236089
# 23 5350652371.834438
# 24 5350631967.599907
# 25 5350611896.004649
# 26 5350592151.611529
# 27 5350572729.072632
# 28 5350553623.127774
# 29 5350534828.603071
# 30 5350516340.409491
# 31 5350498153.54147
# 32 5350480263.075524
# 33 5350462664.168899
# 34 5350445352.058234
# 35 5350428322.058254
# 36 5350411569.560482
# 37 5350395090.031961
# 38 5350378879.014029
# 39 5350362932.121074
# 40 5350347245.039343
# 41 5350331813.52575
# 42 5350316633.406712
# ...

# %%
print(w0,w1,w2,w3)

# %%
# imdb_votes = -1000 + 0.08 release_year + 20 runtime + 10 seasons

# %%
w0=-1000
w1=0.1
w2=20
w3=10
for i in range(100):
 yh=w0+w1*x1+w2*x2+w3*x3
 dew0=-2*((y3-yh)).mean()
 dew1=-2*((y3-yh*x1)).mean()
 dew2=-2*((y3-yh*x2)).mean()
 dew3=-2*((y3-yh*x3)).mean()
 lr=0.0000002
 w0=w0-lr*dew0
 w1=w1-lr*dew1
 w2=w2-lr*dew2
 w3=w3-lr*dew3
 mse=((y3-yh)**2).mean()
 print(i,mse)
# Out:
# 0 139841.32259229344
# 1 139968.2797019909
# 2 139826.94959063645
# 3 139855.3410497416
# 4 139777.56353329628
# 5 139766.68597844636
# 6 139713.8619012733
# 7 139687.4368609861
# 8 139644.45270137856
# 9 139611.89332656612
# 10 139572.80218364042
# 11 139537.83200647903
# 12 139500.289291013
# 13 139464.37938783696
# 14 139427.4600152324
# 15 139391.19128420905
# 16 139354.53013579227
# 17 139318.1319135393
# 18 139281.58486029948
# 19 139245.14767719558
# 20 139208.6578180652
# 21 139172.21740575845
# 22 139135.76227214822
# 23 139099.3327294352
# 24 139062.90344503947
# 25 139026.49033087643
# 26 138990.08338502632
# 27 138953.68888718434
# 28 138917.30288733958
# 29 138880.92786278727
# 30 138844.5622525596
# 31 138808.2070329231
# 32 138771.86158600607
# 33 138735.52629553198
# 34 138699.20091592526
# 35 138662.88559699885
# 36 138626.58024014512
# 37 138590.28490283995
# 38 138553.99954449336
# 39 138517.7241861313
# 40 138481.45881006762
# 41 138445.2034229402
# ...

# %%
print(w0,w1,w2,w3)
# Out:
# -999.9988291687205 0.10432735777114871 19.73061198709565 10.003659237681395

# %%
# tmdb_popularity = -1000 + 0.1 release_year + 20 runtime + 10 seasons

# %%
w0=-1000
w1=0.1
w2=20
w3=10
for i in range(100):
 yh=w0+w1*x1+w2*x2+w3*x3
 dew0=-2*((y4-yh)).mean()
 dew1=-2*((y4-yh*x1)).mean()
 dew2=-2*((y4-yh*x2)).mean()
 dew3=-2*((y4-yh*x3)).mean()
 lr=0.00000021
 w0=w0-lr*dew0
 w1=w1-lr*dew1
 w2=w2-lr*dew2
 w3=w3-lr*dew3
 mse=((y4-yh)**2).mean()
 print(i,mse)
# Out:
# 0 135244.04976501307
# 1 135356.2816647609
# 2 135182.85288237958
# 3 135225.91447900076
# 4 135122.2206077897
# 5 135126.1972328979
# 6 135055.51525455902
# 7 135038.73149109355
# 8 134984.15202323048
# 9 134956.64495608432
# 10 134910.0525267284
# 11 134877.08372434622
# 12 134834.49187035355
# 13 134798.76435805438
# 14 134758.1904564474
# 15 134721.07939585985
# 16 134681.53105341934
# 17 134643.7327015619
# 18 134604.71154237035
# 19 134566.5775745266
# 20 134527.83289521176
# 21 134489.54072435587
# 22 134450.9463013295
# 23 134412.58537159438
# 24 134374.07762386897
# 25 134335.69301240108
# 26 134297.23990312897
# 27 134258.85432085049
# 28 134220.43970259867
# 29 134182.06458779456
# 30 134143.6803182516
# 31 134105.32142842666
# 32 134066.96339861152
# 33 134028.62362864293
# 34 133990.2897618287
# 35 133951.97056411832
# 36 133913.65980758308
# 37 133875.36190768328
# 38 133837.07372468436
# 39 133798.79748189956
# 40 133760.5315956908
# 41 133722.27718478136
# ...

# %%
print(w0,w1,w2,w3)
# Out:
# -999.9996803207314 0.10212993716374985 19.71708794027974 10.003092045001592

# %%
# tmdb_score = -1000 + 0.1 release_year + 20 runtime + 10 seasons
